# %% [markdown]
# # Homework 3
#
# **Total Points: 65 (UG and GR)**
#
# Add your code into the blocks below the prompt. You can add more blocks as needed by clicking the "+" symbol up to the left. This will add a new block below whichever block you have highlighted. You can change the block to be either "code" or "markdown" depending on your needs!
#
# **IMPORTANT: Make sure you add comments to each of your code blocks explaining what is happening so someone else can replicate your code.**

# %% [markdown]
# In this homework, you will start to practice the material from Weeks 1-5. Refer back to the readings from this week for support! For this assignment you will investigate a research question using a dataset of your choice. It can be from the census for a particular place, one of the open data portals we explored in Week 4, or from one of the data sources Jo Klein presented through the library. The requirements on the data are:
# * Must be sufficiently large (>5,000 data points)
# * Must have at least 4 variables of interest (so, at least 4 different columns)
# * Must have a spatial component (so, at least one additional column defines the geometry, or two if lat/lon)
# * Must be from a reputable source (you can trace the origins of the data)
#
# You may need more than one data source to answer your question. If so, only one of the sources needs to satisfy the above requirements.

# %% [markdown]
# ## 3.1 Choosing your data and question (19 points)
#
# In the below cell, describe your data in words. Consider the following questions (or anything else you want to say about the data): Where did it come from? What does it include? What time period and geographic space does it cover? Why did you choose it? What interests you about the data/time/space?

# %% [markdown]
# Explore the data. Compute descripitive stats of your variables of interest.

# %% [markdown]
# Investigate if the data needs any cleaning. If so, clean it. If not, explain why it does not need to be cleaned.

# %% [markdown]
# Based on the data you have, add a question you can explore visually. Your question can be broad: you may not be able to answer it directly from the data, but the instead the data might help you understand a piece of it. Below your question, detail out the steps you will need to take in order to answer your question (e.g., filtering, new columns, grouping, etc).

# %% [markdown]
# ## 3.2 Analyzing your data (11 pts)
#
# In the below cells, conduct the analysis you detailed in the steps above.
#
# You must include at least one instance of:
# * filtering
# * grouping
# * applying a function to one or more columns
# * creating a new column based on existing columns
# * preparing your spatial data for analysis
#
# Not required, but you might find the following analysis helpful:
# * Computing distance
# * Selecting data that is contained in some geometry
#
# If your anaylsis includes these elements naturally, then you can conduct them in any order or in combination with each other where appropriate. If your anaylsis does NOT include these elements naturally, then complete your necessary analysis AND include any of these missing elements in subsequent cells. In this case, think of any additional interesting analysis that could come from these elements.

# %% [markdown]
# ## 3.3 Visualizing your data (30 pts)
#
# In the below cells, visualize your analysis. You must include at least 3 visualizations of different types (scatterplot, heatmap, kde, etc.). **One of the visualizations must be spatial (a map)**. The map can be interactive or static. Where appropriate, make sure you label axes, add titles, add legends, etc.! The figure should be able to be understood on its own without a reader needing to see the code.
#
# Under each visualization, use a markdown cell to give the figure a caption. The caption should be sufficiently detailed for someone to understand the figure on its own without seeing the code. The markdown code should look like this:
#
# **Figure XX**. Detailed caption of figure.
#
# Then, in a cell below each caption, explain what the figure is showing you in words. Use markdown styling to deliminate the description from the caption. What patterns or relationships do you see, if any? What information is presented in the figure? Also include how the visualization choices support your findings (e.g., why is a scatterplot the best choice? Or a boxplot? How does the colormap support your analysis? How does the binning choice support your analysis? etc.)

# %%
# Ex. Figure 1 code here (you can remove these comments)

# %%
# Ex. caption here

# %%
# Ex. explanation here

# %%
# Ex. Figure 2 code here, etc.

# %% [markdown]
# ## 3.4 Conclusions (5 pts)
#
# Finally, include a markdown cell to interpret your findings (descriptive stats and visualizations) in context of your question. Did your findings confirm or refute what you thought? Provide evidence by referencing your findings. Treat this section as if the reader has only skimmed the findings but needs a refresher on how what they show support your overall findings. For example, don't say, "Based on figure 1, transportation in Philly is great" but instead something like, "Because 8/10 of the central Philly census tracts have can access transit within 500m (Figure 1), transportation in Philly is great."
