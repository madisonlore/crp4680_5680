# %% [markdown]
# # Homework 1
#
# Add your code into the blocks below the prompt. You can add more blocks as needed by clicking the "+" symbol up to the left. This will add a new block below whichever block you have highlighted. You can change the block to be either "code" or "markdown" depending on your needs!
#
# IMPORTANT: Make sure you add comments to each of your code blocks explaining what is happening so someone else can replicate your code.

# %% [markdown]
# ## 1.1 Practice with Arithmetic (10 pts)

# %%
# Add code here to determine how many minutes are in 2 hr 55 min 30 seconds

# %%
# Add code here to how many kilometers are in 26.2 miles

# %%
# If you ran a marathon (26.2 miles) in 2 hr 55 min 30 sec, what is your average pace in seconds per kilometer? Add code here

# %%
# What is your average pace in minutes and seconds (standard time format) per kilometer?  
# Round to integer minutes and seconds and print as a string MM:SS/km

# %%
# What is your average pace in minutes and seconds (standard time format) per mile? 
# Round to integer minutes and seconds and print as a string MM:SS/mile

# %% [markdown]
# ## 1.2 Building a Pyramid (10 pts)
#
# Write a function that takes in a number and **prints** a pyramid of *s where the base is that many stars wide. Hint: You can only build a pyramid with odd numbers! So, if your function takes in an even number, print a warning statement instead. For example:
# ```
# def make_pyramid(number):
#     insert code here
# ```
#
# such that if I called `make_pyramid(5)`, it would look like this:
# ```
#   *
#  ***
# *****
# ```
# and if I called `make_pyramid(4)`, it would look like this:
# ```
# Must input odd number to make a pyramid!
# ```

# %% [markdown]
# ## 1.3 Dataframes (10 pts)
#
# Download the accompanying data `ny_census.csv`. Each row represents some census data for census tracts in New York State. The variable names are in columns, where names ending in E are estimates and those ending in M are the margins of error.

# %%
# First import all the packages you need for the rest of the notebook. You can come back to this cell as you go along

# %% [markdown]
# The County column tells you the name of census tract and what county it is in. Determine how many census tracts are in each county and print the top 5 with the most number of tracts.

# %% [markdown]
# Compute the percent of vacant homes in each county. Print the top 5 with the highest percentage and the bottom 5 with the lowest percentage.

# %% [markdown]
# ## 1.4 Descriptive Statistics (14 pts)
#
# Compute the mean and standard deviation of median income in census tracts in one upstate county and one NYC county.

# %% [markdown]
# Describe what you see (add your text here)

# %% [markdown]
# Compute the mean and standard deviation of the percent of commuters who take transit to work in census tracts in the same two counties (one upstate county and one NYC county).

# %% [markdown]
# Describe what you see (add your text here)

# %% [markdown]
# ## 1.5 Plotting (10 pts)
#
# Plot the percent of the population aged 25-34 in each census tract against the percent of housing units that are renter-occupied as a scatter plot. Label all the axes.

# %% [markdown]
# Describe what you see (add your text here)

# %% [markdown]
# ## 1.6 (Graduate students only) (16 pts)
# Undergraduate students, you are welcome to complete this question for practice.

# %% [markdown]
# Write a function that takes in a census tract NAME and returns a dictionary of the percent of white, black, and hispanic identifying people in the population. Present the percentage as a value between 0-100 and round to 2 decimal places.

# %% [markdown]
# Plot the percent of the white idenitfying population vs the median income for census tracts in two counties (one upstate and one in NYC) as a scatter plot. The census tracts in each county should be a different color. Don't forget to label each series and the axes and give it a title and a legend!

# %% [markdown]
# Describe what you see (add your text here)
