# %% [markdown]
# # Homework 2
#
# **(UG) 72 / (G) 92 pts**
#
# Add your code into the blocks below the prompt. You can add more blocks as needed by clicking the "+" symbol up to the left. This will add a new block below whichever block you have highlighted. You can change the block to be either "code" or "markdown" depending on your needs!
#
# IMPORTANT: Make sure you add comments to each of your code blocks explaining what is happening so someone else can replicate your code.
#
# Remember to save your code as a .html file by going to File >> Save and Export Notebook As >> HTML.

# %% [markdown]
# ## 2.1 Data Visualization (10 pts)
#
# Using `seaborn` and our data file `newyork_housing.csv`, plot a kernel density plot of the price of listing housing units for units with 1, 3, and 5 bedrooms. Plot all on the same figure and make sure to include axis labels, a legend, and a title. Beware outliers and erroneous data!

# %% [markdown]
# ## 2.2 Spatial Data (5 pts)
#
# Turn `newyork_housing.csv` into a spatial dataframe (`GeoDataFrame`).

# %% [markdown]
# ## 2.3 Distance metrics (8 pts)
#
# Central Park is described by the following geometry. How many listings from `newyork_housing.csv` are within 1 mile of Central Park?

# %%
from shapely.geometry import Polygon
central_park = gpd.GeoDataFrame(pd.DataFrame({'parkname':['central park'],
                                 'geometry': [Polygon(((-73.9579010, 40.8005561),
                        (-73.9493179, 40.7968525),
                        (-73.9731789, 40.7640313),
                        (-73.9818478, 40.7678667),
                        (-73.9579010, 40.8005561)))]}), 
                                geometry = 'geometry',
                                crs="EPSG:4326")

# %% [markdown]
# ## 2.4 Parking citations (26 pts)
#
# Determine which census tract in Los Angeles County has the most parking citations in January 2024. Hint: what are some of the open data portals we learned about?

# %% [markdown]
# Plot the total number of parking citations in each census tract in Los Angeles for January 2024 as a choropleth map. Add a colorbar with a title!

# %% [markdown]
# Describe what you see in the plot? What information can you gather about the data collection process? What does the analysis tell you?

# %% [markdown]
# ## 2.5 Plotting spatial data from the census (23 pts)
#
# Plot the percent of non-White identifying people by census tract in in the 2020 ACS 5-year census in Alabama. Save out the plot.

# %% [markdown]
# ## 2.6 (Graduate students only) (20 pts)
#
# Plot two side by side plots for census tracts in the San Francisco Bay Area in 2020 of (left) quanitles of the percent of non-White identifying people and (right) quantiles of median household income. Set different color schemes for each side.
