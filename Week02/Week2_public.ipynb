# %% [markdown]
# In class exercise

# %% [markdown]
# **In class exercise**:
# - Judge the result:
#     - (2>1) and (3>18) or (5>4)
#     - not(2>1 or (3<2))

# %%
## your answer here

# %% [markdown]
# ---
#
# **In class exercise**: how to select the element "hello" from the following list? <br>
# ```python
# lst=[1,2,"a",3,4,5,[1,2,"hello"],10,11,100]
# ```
#
# ---

# %%
## your answer here

# %% [markdown]
# ---
# **In class exercise**:
# ```python
# lst = [15,"a",14,64,75,100,110,1000]
# ```
# select a subset [15,"a",14,64,75,100,110] and named it `lst_subset`
#
# ---

# %%
lst = [15,"a",14,64,75,100,110,1000]

## your answer here


## possible other solutions?

# %% [markdown]
# ---
# **In class exercise**:
# ```python
# str1 = 'abcdefg'
# ```
# select a subset named `str2 = 'cde'`
#
# ---

# %%
## your answer here

# %% [markdown]
# **In class exercise:**
#
# `str1 = "      PM25_20141205     "` <br>
# get rid of the prefix "PM25_" and whitespace for str1, and name the new string variable str2

# %%
str1 = "      PM25_20141205     "

# %% [markdown]
# **In class exercise**
#
# You have a student list with grades attached:
# student = ["student1", 99, "student2", 72, "student3", 59]
#
# mark the scores greater than 80 as "A", <br>
# scores between 60 to 80 as "B", <br>
# and scores less than 60 as "C".<br>
# print out the new list student = ['student1', 'A', 'student2', 'B', 'student3', 'C']

# %%
# solution 1 
student = ["student1", 99, "student2", 72, "student3", 59]

# %%
# solution 2 
student = ["student1", 99, "student2", 72, "student3", 59]

# %%
#solution 3
student = ["student1", 99, "student2", 72, "student3", 59]

# Iterate through the list and replace scores with grades

# %% [markdown]
# **In-Class Exercise**:
#
# Designing a Function to Convert Weight from Pounds to Kilograms.
# - weight_in_kilograms=weight_in_pounds×0.45359237

# %%
def convert_to_kilograms(weight_in_pounds):
    
    weight_in_kilog = weight_in_pounds * 0.45359237
    return weight_in_kilog

# Example weight in pounds
weight_in_pounds = 140  

# Call the function and print the result
weight_in_kilograms =

print("Weight in pounds:" + =
print("Weight in kilograms:" + str(weight_in_kilograms))

## can we try uysing the f function?

# %%
def calculate_bmi(weight, height):
    """
    Calculate BMI given weight in kilograms and height in meters.
    
    Parameters:
    weight (float): Weight in kilograms.
    height (float): Height in meters.
    
    Returns:
    float: The calculated BMI value.
    """
    ## bmi is weight divided by height-squared
    bmi =

def bmi_category(bmi):
    """
    Determine the BMI category based on the BMI value.
    
    Parameters:
    bmi (float): The calculated BMI value.
    
    Returns:
    str: The category of the BMI.
    """
    ## definition - bmi less than 18.5 is underweight, 18.5- 25 is normal weight,  25-29.9 is considered 
    ## over weight, and 30 or above is considered obese 

    if bmi < 18.5:
        


# Test the functions
# Sample inputs
weight = 70  # in kilograms
height = 1.75  # in meters

# Calculate BMI
bmi_value = calculate_bmi(weight, height)
# Determine BMI category
category = bmi_category(bmi_value)

# Print the results
