# %% [markdown]
# # CRP 4680/5680 Mid Term Prep

# %% [markdown]
# ## String, Floats and Integers

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
x= 4.8
print(int(x))
# Out:
# 4

# %% [markdown]
# ## Dataframes

# %%
import pandas as pd
import datetime as dt
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Building from Dictionaries

# %%
city_names = ["Ithaca", "New York City", "Albany", "Elmira", "Syracuse"]
city_populations = [32108, 20100000,  99224,26523,148620]
city_medincome = [31169, 38293, 26918, 27292, 38794]

# A pandas dataframe is defined by pd.DataFrame()
# Often times we call it a "df" : dataframe
city_df = pd.DataFrame({'City':city_names,
                        'Population':city_populations,
                        'MedIncome': city_medincome})

# What structure is inside the DataFrame() call?
city_df
# Out:
#             City  Population  MedIncome
# 0         Ithaca       32108      31169
# 1  New York City    20100000      38293
# 2         Albany       99224      26918
# 3         Elmira       26523      27292
# 4       Syracuse      148620      38794

# %% [markdown]
# ### Working with CSV files

# %%
parking = pd.read_csv('parking_citations.csv')
parking.head()
# Out:
# /var/folders/s7/f39th_ms4knd5dm45hnn81dc0000gn/T/ipykernel_432/919954895.py:1: DtypeWarning: Columns (0,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   parking = pd.read_csv('parking_citations.csv')
#   ticket_number               issue_date issue_time meter_id  marked_time  \
# 0    1129198954  2024 Jan 01 12:00:00 AM      1,724      NaN            0
# 1    4578090661  2024 Jan 01 12:00:00 AM        220      NaN            0
# 2    4577607156  2024 Jan 01 12:00:00 AM        249      NaN            0
# 3    4577667426  2024 Jan 01 12:00:00 AM        318      NaN            0
# 4    4577607123  2024 Jan 01 12:00:00 AM        229      NaN            0
#
#   rp_state_plate  plate_expiry_date  vin  make body_style  ... agency  \
# 0             CA                  0  NaN  TOYO        NaN  ...      2
# 1             CA             202308  NaN  HOND         PA  ...     56
# 2             CA             202306  NaN  TOYT         PU  ...     53
# 3             CA             202408  NaN  JEEP         PA  ...     54
# 4             CA             202403  NaN  HOND         PA  ...     53
#
#   violation_code             violation_description  fine_amount  \
# 0            NaN                               NaN           58
# 1       4000(a)1              EXPIRED REGISTRATION           50
# 2          88.66  ELECTRIC CHARGING STATION SPACES           58
# 3           5200                 DISPLAY OF PLATES           25
# 4          22514                      FIRE HYDRANT           68
#
#             agency_desc color_desc body_style_desc    loc_lat    loc_long  \
# 0           LAX CURRENT        NaN             NaN  33.942089 -118.404577
# 1    56 - DOT - CENTRAL     SILVER   PASSENGER CAR  34.053516 -118.276019
# 2     53 - DOT - VALLEY       GREY   PICK-UP TRUCK  34.190315 -118.548174
# 3  54 - DOT - HOLLYWOOD      WHITE   PASSENGER CAR  34.104186 -118.309133
# 4     53 - DOT - VALLEY      BLACK   PASSENGER CAR  34.200874 -118.525018
#
#                    geocodelocation
# 0    POINT (-118.404577 33.942089)
# 1  POINT (-118.2760192 34.0535159)
# 2  POINT (-118.5481743 34.1903155)
# 3  POINT (-118.3091334 34.1041856)
# 4  POINT (-118.5250176 34.2008738)
#
# [5 rows x 23 columns]

# %%
## access the columns with list

# %%
## take a look at the data types

# %%
## show 2nd-5th columns of the dataframe

# %%
### show the last two rows of the df

# %%
### show the last 2 columns and first 5 rows

# %%
## change fine amount from string to an integer

# %%
## find rows where fine amount is an na value

# %%
## replace the na values with the mode of the fine amounts using the lambda apply function

# %%
## filter for cars with the make JEEP or TOYO or CHEV
## try using the df['columns'] == value formate

# %%
## now repeat the same exercise using the isin()

# %%
## how many citations are there or each of the filtered car makes

# %%
## which car make has the highest fine amount

# %% [markdown]
# ### Geodataframe, Geopandas and Census

# %%
## make the df into a gdf

# %%
## bring the TIGER lines for LA 

year = 2020
state_fips = "06"

url = f"https://www2.census.gov/geo/tiger/TIGER{year}/TRACT/tl_{year}_{state_fips}_tract.zip"

tracts = gpd.read_file(url)
tracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      029  004402  06029004402    44.02    Census Tract 44.02  G5020
# 1      06      047  000802  06047000802     8.02     Census Tract 8.02  G5020
# 2      06      085  501402  06085501402  5014.02  Census Tract 5014.02  G5020
# 3      06      005  000102  06005000102     1.02     Census Tract 1.02  G5020
# 4      06      029  004901  06029004901    49.01    Census Tract 49.01  G5020
#
#   FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0        S    1865739        0  +35.5917343  -119.3337642
# 1        S    2321653        0  +37.3433591  -120.5854604
# 2        S     522620        0  +37.3453341  -121.8665169
# 3        S  456204155  7940832  +38.5496993  -120.2509786
# 4        S    1459379        0  +35.7837173  -119.2462266
#
#                                             geometry
# 0  POLYGON ((-119.33828 35.58143, -119.33827 35.5...
# 1  POLYGON ((-120.59599 37.34121, -120.59596 37.3...
# 2  POLYGON ((-121.87381 37.34412, -121.87361 37.3...
# 3  POLYGON ((-120.61016 38.4156, -120.61 38.41577...
# 4  POLYGON ((-119.25262 35.79043, -119.25259 35.7...

# %%
from census import Census
from us import states
from key import CENSUS_KEY

# %%
states.CA.fips
# Out:
# '06'

# %%
## bring in census data for la county

c= Census(CENSUS_KEY)

la_tracts = c.acs5.get( # start here each time
    ('B01001_001E', 'B01001_004E', 'B01001_005E', 'B01001_006E'), # specify the variables we want
    {'for': 'tract:*', # specify the geometry resolution we want
     'in': 'state:06 county:037'}, # speciffy the geometry bounds. In this case, the state of NY
    year=2020, # specify the year
)

# %%
la_df = pd.DataFrame(la_tracts)
la_df.head()
# Out:
#    B01001_001E  B01001_004E  B01001_005E  B01001_006E state county   tract
# 0       3006.0         49.0         70.0         17.0    06    037  199700
# 1       3618.0        279.0         86.0        100.0    06    037  199801
# 2       2419.0        129.0         50.0         50.0    06    037  199802
# 3       2687.0        112.0         98.0         33.0    06    037  199900
# 4       2203.0         18.0         37.0         30.0    06    037  201110

# %%
## in the la_df create a new column called GEOID

# %%
## merge the tracts with the la_tracts data set

# %%
## rename B01001_001E to total_pop, B01001_004E to male_under5, B01001_005E to male_5to9 and B01001_006E to male_10to14

merged = merged.rename(columns = {'B01001_001E' : 'total_pop',
                         'B01001_004E' : 'male_under5',
                         'B01001_005E' : 'male_5to9',
                         'B01001_006E' : 'male_10to14'
                        })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 ## rename B01001_001E to total_pop, B01001_004E to male_under5, B01001_005E to male_5to9 and B01001_006E to male_10to14
# ----> 3 merged = merged.rename(columns = {'B01001_001E' : 'total_pop',
#       4                          'B01001_004E' : 'male_under5',
#       5                          'B01001_005E' : 'male_5to9',
#       6                          'B01001_006E' : 'male_10to14'
#       7                         })
#
# NameError: name 'merged' is not defined

# %%
## plot the JEEP and TOYOTA car makes and the number of total population in each tract 

fig, ax= plt.subplots(1,2, figsize = (10,8))

make_geo =

# %% [markdown]
# ### Spatial Weights

# %%
from libpysal import io
from libpysal import weights

# %%
##using the merged data set create knn = 6 weights matrix

# %%
## create a spatially lagged total population variable
