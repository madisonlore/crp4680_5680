# %% [markdown]
# # Recap Weeks 1-6
#
# In groups, work through these problems to practice the material we have learned so far.

# %% [markdown]
# ## Problem 1.

# %% [markdown]
# Download the parking citations file `parking_citations.csv` from Canvas.

# %%
# Imports and Read in the file

# %%
# Calcuate descriptive statistics about the data

# %%
# Clean the datetime, plate expiry, and violation columns

# %%
# What violation type is most common?

# %%
# Excluding passenger vehicles, what violation type is most common?

# %%
# For each vehicle color, what is the average fine amount?

# %%
# Turn it into a geospatial dataframe (GeoDataFrame)

# %%
# Plot two plots side by side: 
# on the left, locations of fines for California plates 
# on the right, locations of fines for non-California plates

# %%
# Run a simple regression to see if the color of your car impacts your fine amount

# %% [markdown]
# ## Problem 2.
#
# Query for census data in Mississippi.

# %%
# Query the census API for the following variables for census tracts in Mississippi
# total population, total white, total black, total asian, total hispanic, 
# median income, total with bachelors degree or higher

# %%
# Create percentage columns based on total population

# %%
# Get the census tract geometry outlines

# %%
# Combine the two dataframes so that each row is a census tract with data and geometries

# %%
# Calculate density as person per sq km (hint: ALAND is the area of the census tract)

# %%
# Create a new dataframe that groups the data by county and computes the average and standard deviation of % white

# %%
# Sort the counties in order by average % white and plot the values
# (Hint: your x-axis is % white and your y-axis is the ordered counties)

# %%
# Plot the map of density of each census tract. Separate into quintiles

# %% [markdown]
# ## Problem 3
#
# Query the census and run a multiple regression.

# %%
# Query the census API for the following variables for census tracts in Mississippi
# total population, total white, total black, total asian, total hispanic, 
# median income, total with bachelors degree or higher

# %%
# Create percentage columns based on total population

# %%
# Visually check if the percentage columns and median income look normally distributed (histograms)
# Plot them as a grid of figures (3 columns by 2 rows)

# %%
# Visually check if the % race and ethnicity columns look linear with median income
# Hint: plot a scatter plot with each on the x-axis and median income on the y-axis
# Plot them as a grid of figures (2 columns by 2 rows)

# %%
# Run a multiple regression of median income on these percentage columns [model 1]

# %%
# Interpret the model as a whole (R2, p-values, relationships between predictors and outcome)

# %%
# Interpret the coefficient of % white as a sentence

# %%
# Run a multiple regression of log(median income) on the percentge columns [model 2]

# %%
# Compare the results of the model 2 to model 1

# %%
# Interpret the coefficient of % white as a sentence
